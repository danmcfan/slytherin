# %%
# %matplotlib widget

from slytherin.hw5 import plot_happiness_3d

if __name__ == "__main__":
    plot_happiness_3d()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
